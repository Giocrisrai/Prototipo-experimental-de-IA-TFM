# %% [markdown]
# <a href="https://colab.research.google.com/github/Giocrisrai/Inteligencia_artificial_proyecto_master/blob/main/Transformacion_data_croco_tfm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exploración de los datos provenientes del modelo CROCO-OCEAN proveniente de las Islas Clarence al sur de Chile

# %% [markdown]
# ### Librerias

# %%
import os
import datetime

import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')
import datetime
import h5py
import netCDF4 as nc
from netCDF4 import num2date, date2num, date2index


import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Funciones

# %% [markdown]
# #### Permite ver las dimensiones del dataset en formato nc

# %%
def dimensiones(data):
  for dim in data.dimensions.values():
    print(dim)

# %% [markdown]
# #### Permite visualizar los valores de las variables del dataset en formato nc

# %%
def variab (data):
  for var in data.variables.values():
    print(var)

# %% [markdown]
# #### Permite recorrer el DataFrame para llenar con los datos de la capa

# %% [markdown]
# ### Archivo

# %%
modeType   = 'r'
fileFormat = 'NETCDF4'

# %%
url = '/Volumes/Machintosh hd1/croco_his3feb_mar/croco_his3feb_mar.nc.4'
ds = nc.Dataset(url, mode=modeType, format=fileFormat)
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     type: ROMS history file
#     title: BENGUELA TEST MODEL ZOOM LEVEL #4
#     date:
#     rst_file: /media/usuario/DATA/croco/rclarence/salidasi/croco_rst3.nc.4
#     his_file: /media/usuario/DATA/croco/rclarence/salidasi/croco_his3.nc.4
#     avg_file: /media/usuario/DATA/croco/rclarence/salidasi/croco_avg3.nc.4
#     grd_file: /media/usuario/DATA/croco/rclarence/entradasi/croco_grd.nc.4
#     ini_file: /media/usuario/DATA/croco/rclarence/entradasi/croco_ini.nc.4
#     frc_file: /media/usuario/DATA/croco/rclarence/entradasi/croco_frc.nc.4
#     VertCoordType: NEW
#     skpp: 2005
#     theta_s: 6.0
#     theta_s_expl: S-coordinate surface control parameter
#     theta_b: 0.0
#     theta_b_expl: S-coordinate bottom control parameter
#     Tcline: 70.0
#     Tcline_expl: S-coordinate surface/bottom layer width
#     Tcline_units: meter
#     hc: 70.0
# ...

# %% [markdown]
# #### Coordenadas de trabajo

# %%
xj = 70
yj = 36

# %% [markdown]
# #### Información del dataset

# %%
ds.variables.keys()
# Out:
# dict_keys(['spherical', 'xl', 'el', 'xi_rho', 'xi_u', 'eta_rho', 'eta_v', 'Vtransform', 's_rho', 's_w', 'sc_r', 'sc_w', 'Cs_r', 'Cs_w', 'hc', 'h', 'f', 'pm', 'pn', 'lon_rho', 'lat_rho', 'lon_u', 'lat_u', 'lon_v', 'lat_v', 'angle', 'mask_rho', 'time_step', 'scrum_time', 'time', 'zeta', 'ubar', 'vbar', 'u', 'v', 'temp', 'salt', 'DIC', 'TALK', 'O2', 'CACO3', 'PO4', 'POC', 'Si', 'NANO', 'ZOO', 'DOC', 'DIA', 'MESO', 'BSI', 'FER', 'BFE', 'GOC', 'SFE', 'DFE', 'DSI', 'NFE', 'NCHL', 'DCHL', 'NO3', 'NH4', 'w', 'bostr', 'wstr', 'sustr', 'svstr', 'AKt', 'hbl', 'hbbl', 'shflux', 'swflux', 'swrad'])

# %% [markdown]
# #### Dimensiones de las variables del dataset

# %%
dimensiones(ds)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'xi_rho', size = 182
# <class 'netCDF4._netCDF4.Dimension'>: name = 'xi_u', size = 181
# <class 'netCDF4._netCDF4.Dimension'>: name = 'eta_rho', size = 311
# <class 'netCDF4._netCDF4.Dimension'>: name = 'eta_v', size = 310
# <class 'netCDF4._netCDF4.Dimension'>: name = 's_rho', size = 30
# <class 'netCDF4._netCDF4.Dimension'>: name = 's_w', size = 31
# <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 1023
# <class 'netCDF4._netCDF4.Dimension'>: name = 'auxil', size = 4

# %% [markdown]
# #### Variables del data set como estan constituidos

# %%
variab(ds)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# |S1 spherical()
#     long_name: grid type logical switch
#     option_T: spherical
#     option_F: cartesian
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# float32 xl()
#     long_name: domain length in the XI-direction
#     units: meter
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 el()
#     long_name: domain length in the ETA-direction
#     units: meter
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 xi_rho(xi_rho)
#     long_name: x-dimension of the grid
#     standard_name: x_grid_index
#     axis: X
#     c_grid_dynamic_range: 2:181
# unlimited dimensions:
# current shape = (182,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# ...

# %% [markdown]
# #### Se guardan las variables para poder manipularlos de mejor manera

# %%
spherical = ds.variables['spherical']
xl = ds.variables['xl']
el = ds.variables['el']
xi_rho = ds.variables['xi_rho']
xi_u = ds.variables['xi_u']
eta_rho = ds.variables['eta_rho']
eta_v = ds.variables['eta_v']
Vtransform = ds.variables['Vtransform']
time = ds.variables['time']
s_rho = ds.variables['s_rho']
s_w = ds.variables['s_w']
sc_r = ds.variables['sc_r']
sc_w = ds.variables['sc_w']
Cs_r = ds.variables['Cs_r']
Cs_w = ds.variables['Cs_w']
hc = ds.variables['hc']
h = ds.variables['h']
f = ds.variables['f']
pm = ds.variables['pm']
pn = ds.variables['pn']
lon_rho = ds.variables['lon_rho']
lat_rho = ds.variables['lat_rho']
lon_u = ds.variables['lon_u']
lat_u = ds.variables['lat_u']
lon_v = ds.variables['lon_v']
lat_v = ds.variables['lat_v']
angle = ds.variables['angle']
mask_rho = ds.variables['mask_rho']
time_step = ds.variables['time_step']
scrum_time = ds.variables['scrum_time']
time = ds.variables['time']
zeta = ds.variables['zeta']
ubar = ds.variables['ubar']
vbar = ds.variables['vbar']
u = ds.variables['u']
v = ds.variables['v']
temp = ds.variables['temp']
salt = ds.variables['salt']
DIC = ds.variables['DIC']
TALK = ds.variables['TALK']
O2 = ds.variables['O2']
CACO3 = ds.variables['CACO3']
PO4 = ds.variables['PO4']
POC = ds.variables['POC']
Si = ds.variables['Si']
NANO = ds.variables['NANO']
ZOO = ds.variables['ZOO']
DOC = ds.variables['DOC']
DIA = ds.variables['DIA']
MESO = ds.variables['MESO']
BSI = ds.variables['BSI']
FER = ds.variables['FER']
BFE = ds.variables['BFE']
GOC = ds.variables['GOC']
SFE = ds.variables['SFE']
DFE = ds.variables['DFE']
DSI = ds.variables['DSI']
NFE = ds.variables['NFE']
NCHL = ds.variables['NCHL']
DCHL = ds.variables['DCHL']
NO3 = ds.variables['NO3']
NH4 = ds.variables['NH4']
w = ds.variables['w']
bostr = ds.variables['bostr']
wstr = ds.variables['wstr']
sustr = ds.variables['sustr']
svstr = ds.variables['svstr']
AKt = ds.variables['AKt']
hbl = ds.variables['hbl']
hbbl = ds.variables['hbbl']
shflux = ds.variables['shflux']
swflux = ds.variables['swflux']
swrad = ds.variables['swrad']

# %%
print('spherical'+ ' '+ str(spherical.dimensions))
print('xl'+ ' '+ str(xl.dimensions))
print('el'+ ' '+ str(el.dimensions))
print('xi_rho'+ ' '+ str(xi_rho.dimensions))
print('xi_u'+ ' '+ str(xi_u.dimensions))
print('eta_rho'+ ' '+ str(eta_rho.dimensions))
print('eta_v'+ ' '+ str(eta_v.dimensions))
print('Vtransform'+ ' '+ str(Vtransform.dimensions))
print('time'+ ' '+ str(time.dimensions))
print('s_rho'+ ' '+ str(s_rho.dimensions))
print('s_w'+ ' '+ str(s_w.dimensions))
print('sc_r'+ ' '+ str(sc_r.dimensions))
print('sc_w'+ ' '+ str(sc_w.dimensions))
print('Cs_r'+ ' '+ str(Cs_r.dimensions))
print('Cs_w'+ ' '+ str(Cs_w.dimensions))
print('hc'+ ' '+ str(hc.dimensions))
print('h'+ ' '+ str(h.dimensions))
print('f'+ ' '+ str(f.dimensions))
print('pm'+ ' '+ str(pm.dimensions))
print('pn'+ ' '+ str(pn.dimensions))
print('lon_rho'+ ' '+ str(lon_rho.dimensions))
print('lat_rho'+ ' '+ str(lat_rho.dimensions))
print('lon_u'+ ' '+ str(lon_u.dimensions))
print('lat_u'+ ' '+ str(lat_u.dimensions))
print('lon_v'+ ' '+ str(lon_v.dimensions))
print('lat_v'+ ' '+ str(lat_v.dimensions))
print('angle'+ ' '+ str(angle.dimensions))
print('mask_rho'+ ' '+ str(mask_rho.dimensions))
print('time_step'+ ' '+ str(time_step.dimensions))
print('scrum_time'+ ' '+ str(scrum_time.dimensions))
print('time'+ ' '+ str(time.dimensions))
print('zeta'+ ' '+ str(zeta.dimensions))
print('ubar'+ ' '+ str(ubar.dimensions))
print('vbar'+ ' '+ str(vbar.dimensions))
print('u'+ ' '+ str(u.dimensions))
print('v'+ ' '+ str(v.dimensions))
print('temp'+ ' '+ str(temp.dimensions))
print('salt'+ ' '+ str(salt.dimensions))
print('DIC'+ ' '+ str(DIC.dimensions))
print('TALK'+ ' '+ str(TALK.dimensions))
print('O2'+ ' '+ str(O2.dimensions))
print('CACO3'+ ' '+ str(CACO3.dimensions))
print('PO4'+ ' '+ str(PO4.dimensions))
print('POC'+ ' '+ str(POC.dimensions))
print('Si'+ ' '+ str(Si.dimensions))
print('NANO'+ ' '+ str(NANO.dimensions))
print('ZOO'+ ' '+ str(ZOO.dimensions))
print('DOC'+ ' '+ str(DOC.dimensions))
print('DIA'+ ' '+ str(DIA.dimensions))
print('MESO'+ ' '+ str(MESO.dimensions))
print('BSI'+ ' '+ str(BSI.dimensions))
print('FER'+ ' '+ str(FER.dimensions))
print('BFE'+ ' '+ str(BFE.dimensions))
print('GOC'+ ' '+ str(GOC.dimensions))
print('SFE'+ ' '+ str(SFE.dimensions))
print('DFE'+ ' '+ str(DFE.dimensions))
print('DSI'+ ' '+ str(DSI.dimensions))
print('NFE'+ ' '+ str(NFE.dimensions))
print('NCHL'+ ' '+ str(NCHL.dimensions))
print('DCHL'+ ' '+ str(DCHL.dimensions))
print('NO3'+ ' '+ str(NO3.dimensions))
print('NH4'+ ' '+ str(NH4.dimensions))
print('w'+ ' '+ str(w.dimensions))
print('bostr'+ ' '+ str(bostr.dimensions))
print('wstr'+ ' '+ str(wstr.dimensions))
print('sustr'+ ' '+ str(sustr.dimensions))
print('svstr'+ ' '+ str(svstr.dimensions))
print('AKt'+ ' '+ str(AKt.dimensions))
print('hbl'+ ' '+ str(hbl.dimensions))
print('hbbl'+ ' '+ str(hbbl.dimensions))
print('shflux'+ ' '+ str(shflux.dimensions))
print('swflux'+ ' '+ str(swflux.dimensions))
print('swrad'+ ' '+ str(swrad.dimensions))
# Out:
# spherical ()
# xl ()
# el ()
# xi_rho ('xi_rho',)
# xi_u ('xi_u',)
# eta_rho ('eta_rho',)
# eta_v ('eta_v',)
# Vtransform ()
# time ('time',)
# s_rho ('s_rho',)
# s_w ('s_w',)
# sc_r ('s_rho',)
# sc_w ('s_w',)
# Cs_r ('s_rho',)
# Cs_w ('s_w',)
# hc ()
# h ('eta_rho', 'xi_rho')
# f ('eta_rho', 'xi_rho')
# pm ('eta_rho', 'xi_rho')
# pn ('eta_rho', 'xi_rho')
# lon_rho ('eta_rho', 'xi_rho')
# lat_rho ('eta_rho', 'xi_rho')
# lon_u ('eta_rho', 'xi_u')
# lat_u ('eta_rho', 'xi_u')
# lon_v ('eta_v', 'xi_rho')
# lat_v ('eta_v', 'xi_rho')
# angle ('eta_rho', 'xi_rho')
# mask_rho ('eta_rho', 'xi_rho')
# time_step ('time', 'auxil')
# scrum_time ('time',)
# time ('time',)
# zeta ('time', 'eta_rho', 'xi_rho')
# ubar ('time', 'eta_rho', 'xi_u')
# vbar ('time', 'eta_v', 'xi_rho')
# u ('time', 's_rho', 'eta_rho', 'xi_u')
# v ('time', 's_rho', 'eta_v', 'xi_rho')
# temp ('time', 's_rho', 'eta_rho', 'xi_rho')
# salt ('time', 's_rho', 'eta_rho', 'xi_rho')
# DIC ('time', 's_rho', 'eta_rho', 'xi_rho')
# ...

# %% [markdown]
# ### Creación de DataFrame con la información proveniente del conjunto de datos

# %%
s_rho_array = np.array(ds.variables['s_rho'][:])
s_rho_array
# Out:
# array([-0.98333335, -0.95      , -0.9166667 , -0.8833333 , -0.85      ,
#        -0.81666666, -0.78333336, -0.75      , -0.71666664, -0.68333334,
#        -0.65      , -0.6166667 , -0.5833333 , -0.55      , -0.51666665,
#        -0.48333332, -0.45      , -0.41666666, -0.38333333, -0.35      ,
#        -0.31666666, -0.28333333, -0.25      , -0.21666667, -0.18333334,
#        -0.15      , -0.11666667, -0.08333334, -0.05      , -0.01666667],
#       dtype=float32)

# %%
dt = np.arange(0,ds.variables['time'].size)
dt
# Out:
# array([   0,    1,    2, ..., 1020, 1021, 1022])

# %%
columns = ['time'+ ' '+ str(time.units),
           'u'+ ' '+ str(u.units),
           'v'+ ' '+ str(v.units),
           'temp'+ ' '+ str(temp.units),
           'salt'+ ' '+ str(salt.units),
           'DIC'+ ' '+ str(DIC.units),
           'TALK'+ ' '+ str(TALK.units),
           'O2'+ ' '+ str(O2.units),
           'CACO3'+ ' '+ str(CACO3.units),
           'PO4'+ ' '+ str(PO4.units),
           'POC'+ ' '+ str(POC.units),
           'Si'+ ' '+ str(Si.units),
           'NANO'+ ' '+ str(NANO.units),
           'ZOO'+ ' '+ str(ZOO.units),
           'DOC'+ ' '+ str(DOC.units),
           'DIA'+ ' '+ str(DIA.units),
           'MESO'+ ' '+ str(MESO.units),
           'BSI'+ ' '+ str(BSI.units),
           'FER'+ ' '+ str(FER.units),
           'BFE'+ ' '+ str(BFE.units),
           'GOC'+ ' '+ str(GOC.units),
           'SFE'+ ' '+ str(SFE.units),
           'DFE'+ ' '+ str(DFE.units),
           'DSI'+ ' '+ str(DSI.units),
           'NFE'+ ' '+ str(NFE.units),
           'NCHL'+ ' '+ str(NCHL.units),
           'DCHL'+ ' '+ str(DCHL.units),
           'NO3'+ ' '+ str(NO3.units),
           'NH4'+ ' '+ str(NH4.units),
           'w'+ ' '+ str(w.units)]

# %%
def llenar_df(capa):
    
    """Creación del DataFrame Vacio"""
    
    data = pd.DataFrame(0, columns = columns,index = dt)
    
    """Llenado del Dataframe con el indice de la capa"""
    for time_index in range(len(data)):
        
        #Data con formato ('time')
        data.loc[time_index,'time second'] = time[time_index]
        
        #Data con formato ('time', 's_rho', 'eta_rho', 'xi_rho')
        data.loc[time_index,'u meter second-1'] = u[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'v meter second-1'] = v[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'temp Celsius'] = temp[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'salt PSU'] = salt[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'DIC umol C L-1'] = DIC[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'TALK umol C L-1'] = TALK[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'O2 umol L-1'] = O2[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'CACO3 umol C L-1'] = CACO3[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'PO4 umol P L-1'] = PO4[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'POC umol C L-1'] = POC[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'Si umol Si L-1'] = Si[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'NANO umol C L-1'] = NANO[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'ZOO umol C L-1'] = ZOO[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'DOC umol C L-1'] = DOC[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'DIA umol C L-1'] = DIA[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'MESO umol C L-1'] = MESO[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'BSI umol Si L-1'] = BSI[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'FER umol Fe L-1'] = FER[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'BFE umol Fe L-1'] = BFE[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'GOC umol C L-1'] = GOC[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'SFE umol Fe L-1'] = SFE[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'DFE umol Fe L-1'] = DFE[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'DSI umol Si L-1'] = DSI[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'NFE umol Fe L-1'] = NFE[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'NCHL mg Chl m-3'] = NCHL[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'DCHL mg Chl m-3'] = DCHL[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'NO3 umol N L-1'] = NO3[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'NH4 umol N L-1'] = NH4[time_index,s_rho_array[capa],yj,xj]
        data.loc[time_index,'w meter second-1'] = w[time_index,s_rho_array[capa],yj,xj]
    
    return data

# %% [markdown]
# ### Guardar la serie temporal en formato CSV

# %%
j = s_rho_array.size
for i in range(j):
    df = llenar_df(i)
    df.to_csv('data_croco_febr_marz_capa_'+str(i)+'.csv',index=False)
    print(df)
# Out:
#       time second  u meter second-1  v meter second-1  temp Celsius  \
# 0       3542400.0         -0.000000         -0.000000      5.886886
# 1       3546000.0          0.029425         -0.004129      5.886886
# 2       3549600.0          0.018897         -0.006286      5.886885
# 3       3553200.0         -0.007290          0.001888      5.886994
# 4       3556800.0          0.055234          0.034601      5.861478
# ...           ...               ...               ...           ...
# 1018    7207200.0          0.231011         -0.085812      7.396721
# 1019    7210800.0          0.327456         -0.072241      7.383870
# 1020    7214400.0          0.397913         -0.129356      7.398913
# 1021    7218000.0          0.348203         -0.176570      7.401522
# 1022    7221600.0          0.214899         -0.151948      7.420812
#
#        salt PSU  DIC umol C L-1  TALK umol C L-1  O2 umol L-1  \
# 0     34.166729     2143.533691      2309.043945   294.850098
# ...

# %%
dt = np.arange(0,ds.variables['time'].size)
df_time = pd.DataFrame(0, columns = ['time'],index = dt)

# %%
for time_index in dt:
        df_time.iloc[time_index] = time[time_index]

# %%
df_time
# Out:
#            time
# 0     3542400.0
# 1     3546000.0
# 2     3549600.0
# 3     3553200.0
# 4     3556800.0
# ...         ...
# 1018  7207200.0
# 1019  7210800.0
# 1020  7214400.0
# 1021  7218000.0
# 1022  7221600.0
#
# [1023 rows x 1 columns]

# %%
df_time.to_csv('data_croco_febr_marz_time.csv',index=False)

# %% [markdown]
# ### Leer los datos de series temporales guardados en csv

# %%
url_time = '/Users/giocrisraigodoy/data_croco_febr_marz_time.csv'
url_0 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_0.csv'
url_1 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_1.csv'
url_2 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_2.csv'
url_3 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_3.csv'
url_4 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_4.csv'
url_5 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_5.csv'
url_6 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_6.csv'
url_7 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_7.csv'
url_8 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_8.csv'
url_9 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_9.csv'
url_10 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_10.csv'
url_11 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_11.csv'
url_12 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_12.csv'
url_13 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_13.csv'
url_14 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_14.csv'
url_15 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_15.csv'
url_16 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_16.csv'
url_17 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_17.csv'
url_18 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_18.csv'
url_19 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_19.csv'
url_20 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_20.csv'
url_21 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_21.csv'
url_22 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_22.csv'
url_23 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_23.csv'
url_24 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_24.csv'
url_25 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_25.csv'
url_26 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_26.csv'
url_27 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_27.csv'
url_28 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_28.csv'
url_29 = '/Users/giocrisraigodoy/data_croco_febr_marz_capa_29.csv'

# %%
df0 = pd.read_csv(url_0)
df1 = pd.read_csv(url_1)
df2 = pd.read_csv(url_2)
df3 = pd.read_csv(url_3)
df4 = pd.read_csv(url_4)
df5 = pd.read_csv(url_5)
df6 = pd.read_csv(url_6)
df7 = pd.read_csv(url_7)
df8 = pd.read_csv(url_8)
df9 = pd.read_csv(url_9)
df10 = pd.read_csv(url_10)
df11 = pd.read_csv(url_11)
df12 = pd.read_csv(url_12)
df13 = pd.read_csv(url_13)
df14 = pd.read_csv(url_14)
df15 = pd.read_csv(url_15)
df16 = pd.read_csv(url_16)
df17 = pd.read_csv(url_17)
df18 = pd.read_csv(url_18)
df19 = pd.read_csv(url_19)
df20 = pd.read_csv(url_20)
df21 = pd.read_csv(url_21)
df22 = pd.read_csv(url_22)
df23 = pd.read_csv(url_23)
df24 = pd.read_csv(url_24)
df25 = pd.read_csv(url_25)
df26 = pd.read_csv(url_26)
df27 = pd.read_csv(url_27)
df28 = pd.read_csv(url_28)
df29 = pd.read_csv(url_29)

# %%
dataframes_verano = [df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,
                     df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,
                     df21,df22,df23,df24,df25,df26,df27,df28,df29]

# %%
data_verano = pd.concat(dataframes_verano, sort='True',ignore_index='True')
data_verano
# Out:
#        BFE umol Fe L-1  BSI umol Si L-1  CACO3 umol C L-1  DCHL mg Chl m-3  \
# 0         5.000000e-08         0.001500          0.010000         0.002182
# 1         4.987527e-08         0.001501          0.009986         0.002184
# 2         4.976000e-08         0.001502          0.009972         0.002189
# 3         4.964992e-08         0.001504          0.009958         0.002194
# 4         4.987341e-08         0.001527          0.009986         0.002299
# ...                ...              ...               ...              ...
# 30685     1.093046e-03         0.085635          0.071282         0.123686
# 30686     1.099947e-03         0.082991          0.071495         0.120386
# 30687     1.097965e-03         0.084593          0.069979         0.122374
# 30688     1.094284e-03         0.085013          0.068421         0.122985
# 30689     1.078603e-03         0.089781          0.066629         0.128924
#
# ...

# %%
data_verano.to_csv('data_croco_febr_marz_verano_completa.csv',index=False)
